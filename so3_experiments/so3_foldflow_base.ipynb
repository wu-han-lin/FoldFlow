# %%
# %env GEOMSTATS_BACKEND=pytorch
# Out:
# env: GEOMSTATS_BACKEND=pytorch

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("..")  

import os
import numpy as np
import torch
from einops import rearrange
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import warnings
warnings.filterwarnings('ignore')


from scipy.spatial.transform import Rotation
from geomstats.geometry.special_orthogonal import SpecialOrthogonal

from utils.plotting import plot_so3
from utils.optimal_transport import so3_wasserstein as wasserstein
from foldflow.utils.so3_helpers import norm_SO3, expmap
from foldflow.utils.so3_condflowmatcher import SO3ConditionalFlowMatcher
from so3_experiments.models.models import PMLP

from torch.utils.data import DataLoader
from data.datasets import SpecialOrthogonalGroup

from geomstats._backend import _backend_config as _config
_config.DEFAULT_DTYPE = torch.cuda.FloatTensor 

savedir = "models/so3_synthetic"
os.makedirs(savedir, exist_ok=True)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

# Load toy dataset
data = np.load('data/orthogonal_group.npy')
print('size of toy dataset: ', len(data))

fig = plot_so3(data)
plt.savefig('figs/so3_synthetic_data.png', dpi=300)
plt.show()
# Out:
# cuda:0
# size of toy dataset:  50000

# %% [markdown]
# ### Dataloader

# %%
# load data
trainset = SpecialOrthogonalGroup(split="train")
trainloader = DataLoader(
    trainset, batch_size=1024, shuffle=True, num_workers=0
)

valset = SpecialOrthogonalGroup(split="valid")
valloader = DataLoader(
    valset, batch_size=256, shuffle=False, num_workers=0
)

testset = SpecialOrthogonalGroup(split="test")
testloader = DataLoader(
    testset, batch_size=256, shuffle=False, num_workers=0
)

# %% [markdown]
# ### CFM

# %% [markdown]
# This is an SO(3) CFM it calculates the flow at $r_t$:
#         $$u_t(r_t | r_0, r_1) = \log_{r_t}(r_0)/t$$

# %%
so3_group = SpecialOrthogonal(n=3, point_type="matrix")
FM = SO3ConditionalFlowMatcher(manifold=so3_group)

# %% [markdown]
# ### Loss Function

# %% [markdown]
# The final loss corresponds to equation (3) in the paper:
#
# $$\mathcal{L}_{\mathrm{foldflowbase},-\mathrm{SO(3)}}(\theta) = \mathbb{E}_{t\sim \mathcal{U}(0,1), q(r_0,r_1), \rho_t(r_t | r_0, r_1)} \left \|v_\theta(t, r_t) - \log_{r_t}(r_0)/t\right\|_{\mathrm{SO(3)}}^2$$

# %%
def loss_fn(v, u, x):
    res = v - u
    norm = norm_SO3(x, res) # norm-squared on SO(3)
    loss = torch.mean(norm, dim=-1)
    return loss

# %% [markdown]
# ### ODE Inference

# %%
# ODE inference on SO(3)
def inference(model, xt, t, dt):
    with torch.no_grad():
        vt = model(torch.cat([xt.float(), t[:, None].float()], dim=-1)) # vt on the tanget of xt
        vt = rearrange(vt, 'b (c d) -> b c d', c=3, d=3)
        xt = rearrange(xt, 'b (c d) -> b c d', c=3, d=3)
        xt_new = expmap(xt.float(), (vt * dt).float())                   # expmap to get the next point
    return rearrange(xt_new, 'b c d -> b (c d)', c=3, d=3)

# %% [markdown]
# ### Model

# %%
dim = 9 # network ouput is 9 dimensional (3x3 matrix)

# MLP with a projection at the end, projection on to the tanget space of the manifold
model = PMLP(dim=dim, time_varying=True).to(device)  
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)

# %% [markdown]
# ### Training Loop

# %%
def main_loop(model, optimizer, num_epochs=150, display=True):
    losses = []
    w1ds = []
    w2ds = []
    global_step = 0

    for epoch in range(num_epochs):
        
        if display:
            progress_bar = tqdm(total=len(trainloader))
            progress_bar.set_description(f"Epoch {epoch}")

        if (epoch % 10) == 0:
            n_test = testset.data.shape[0]
            traj = torch.tensor(Rotation.random(n_test).as_matrix()).to(device).reshape(-1, 9)
            for t in torch.linspace(0, 1, 200):
                t = torch.tensor([t]).to(device).repeat(n_test).requires_grad_(True)
                dt = torch.tensor([1/200]).to(device)
                traj = inference(model, traj, t, dt)
            final_traj = rearrange(traj, 'b (c d) -> b c d', c=3, d=3)

            # w_d1 = wasserstein(torch.tensor(testset.data).to(device).double().detach(), final_traj.detach(), power=1)
            # w_d2 = wasserstein(torch.tensor(testset.data).to(device).double().detach(), final_traj.detach(), power=2)
            w_d1 = wasserstein(torch.tensor(testset.data).to(device).float().detach(), final_traj.detach(), power=1)
            w_d2 = wasserstein(torch.tensor(testset.data).to(device).float().detach(), final_traj.detach(), power=2)
            w1ds.append(w_d1)
            w2ds.append(w_d2)

            if display:
                plot_so3(final_traj)
                plt.show()
                print('wassterstein-1 distance:', w_d1)
                print('wassterstein-2 distance:', w_d2)

        for _, data in enumerate(trainloader):
            optimizer.zero_grad()
            x1 = data.to(device)
            x0 = torch.tensor(Rotation.random(x1.size(0)).as_matrix()).to(device)

            t, xt, ut = FM.sample_location_and_conditional_flow_simple(x0.double(), x1.double())

            vt = model(torch.cat([rearrange(xt, 'b c d -> b (c d)', c=3, d=3) , t[:, None]], dim=-1))
            vt = rearrange(vt, 'b (c d) -> b c d', c=3, d=3)

            loss = loss_fn(vt, ut, xt)
            losses.append(loss.detach().cpu().numpy())
             
            loss.backward()
            optimizer.step()

            if display:
                progress_bar.update(1)
                logs = {"loss": loss.detach().item(), "step": global_step}
                progress_bar.set_postfix(**logs)
                global_step += 1

    return model, np.array(losses), np.array(w1ds), np.array(w2ds)

model, losses, w1s, w2s = main_loop(model, optimizer, num_epochs=11, display=True)
# Out:
# wassterstein-1 distance: 0.9380847326766703
# wassterstein-2 distance: 1.100725633992442
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[40], line 59
#      55                 global_step += 1
#      57     return model, np.array(losses), np.array(w1ds), np.array(w2ds)
# ---> 59 model, losses, w1s, w2s = main_loop(model, optimizer, num_epochs=11, display=True)
#
# Cell In[40], line 42, in main_loop(model, optimizer, num_epochs, display)
#      38 x0 = torch.tensor(Rotation.random(x1.size(0)).as_matrix()).to(device)
#      40 t, xt, ut = FM.sample_location_and_conditional_flow_simple(x0.double(), x1.double())
# ---> 42 vt = model(torch.cat([rearrange(xt, 'b c d -> b (c d)', c=3, d=3) , t[:, None]], dim=-1))
#      43 vt = rearrange(vt, 'b (c d) -> b c d', c=3, d=3)
#      45 loss = loss_fn(vt, ut, xt)
#
# File ~/anaconda3/envs/foldflow/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/foldflow/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/FoldFlow/so3_experiments/models/models.py:83, in PMLP.forward(self, input)
#      82 def forward(self, input):
# ---> 83     v = self.net(input)
#      84     x = rearrange(input[:, :-1], "b (c d) -> b c d", c=3, d=3)
#      85     v = rearrange(v, "b (c d) -> b c d", c=3, d=3)
#
# File ~/anaconda3/envs/foldflow/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/foldflow/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/foldflow/lib/python3.10/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/anaconda3/envs/foldflow/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/foldflow/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/foldflow/lib/python3.10/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 must have the same dtype, but got Double and Float

# %% [markdown]
# ### Results for Multiple Runs

# %%
w1ds_runs = []
w2ds_runs = []
losses_runs = []

num_runs = 5

for i in range(num_runs):
    print('doing run ', i)
    model = PMLP(dim=dim, time_varying=True).to(device)  
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)
    model, losses, w1ds, w2ds = main_loop(model, optimizer, num_epochs=80, display=False)

    w1ds_runs.append(w1ds)
    w2ds_runs.append(w2ds)
    losses_runs.append(losses)

losses_runs = np.array(losses_runs)
w1ds_runs = np.array(w1ds_runs)
w2ds_runs = np.array(w2ds_runs)
# Out:
# doing run  0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 11
#       9 model = PMLP(dim=dim, time_varying=True).to(device)
#      10 optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)
# ---> 11 model, losses, w1ds, w2ds = main_loop(model, optimizer, num_epochs=80, display=False)
#      13 w1ds_runs.append(w1ds)
#      14 w2ds_runs.append(w2ds)
#
# Cell In[14], line 22, in main_loop(model, optimizer, num_epochs, display)
#      19     traj = inference(model, traj, t, dt)
#      20 final_traj = rearrange(traj, 'b (c d) -> b c d', c=3, d=3)
# ---> 22 w_d1 = wasserstein(torch.tensor(testset.data).to(device).double().detach(), final_traj.detach(), power=1)
#      23 w_d2 = wasserstein(torch.tensor(testset.data).to(device).double().detach(), final_traj.detach(), power=2)
#      24 w1ds.append(w_d1)
#
# File ~/FoldFlow/so3_experiments/utils/optimal_transport.py:181, in so3_wasserstein(x0, x1, method, reg, power, **kwargs)
#     178     raise ValueError(f"Unknown method: {method}")
#     180 a, b = pot.unif(x0.shape[0]), pot.unif(x1.shape[0])
# --> 181 M = pairwise_geodesic_distance(x0, x1)
#     182 if power == 2:
#     183     M = M**2
#
# File ~/FoldFlow/so3_experiments/utils/optimal_transport.py:36, in pairwise_geodesic_distance(x0, x1)
#      32 mega_batch_x0 = rearrange(
#      33     x0.repeat_interleave(batch_size, dim=0), "b (c d) -> b c d", c=3, d=3
#      34 )
#      35 mega_batch_x1 = rearrange(x1.repeat(batch_size, 1), "b (c d) -> b c d", c=3, d=3)
# ---> 36 distances = so3_relative_angle(mega_batch_x0, mega_batch_x1) ** 2
#      37 return distances.reshape(batch_size, batch_size)
#
# File ~/FoldFlow/foldflow/utils/so3_helpers.py:310, in so3_relative_angle(R1, R2, cos_angle, cos_bound, eps)
#     275 def so3_relative_angle(
#     276     R1: torch.Tensor,
#     277     R2: torch.Tensor,
#    (...)
#     280     eps: float = 1e-4,
#     281 ) -> torch.Tensor:
#     282     """
#     283     Calculates the relative angle (in radians) between pairs of
#     284     rotation matrices `R1` and `R2` with `angle = acos(0.5 * (Trace(R1 R2^T)-1))`
#    (...)
#     308         ValueError if `R1` or `R2` has an unexpected trace.
#     309     """
# --> 310     R12 = torch.bmm(R1, R2.permute(0, 2, 1))
#     311     return so3_rotation_angle(R12)
#
# RuntimeError: expected scalar type Float but found Double

# %% [markdown]
# ### Plot Results

# %%
# mean of w1s
w1s_mean = np.mean(w1ds_runs, axis=0)
w1s_std = np.std(w1ds_runs, axis=0)

# mean of w2s
w2s_mean = np.mean(w2ds_runs, axis=0)
w2s_std = np.std(w2ds_runs, axis=0)

# %%
print('w1s_mean', w1s_mean[-1])
print('w1s_std', w1s_std[-1])
print('w2s_mean', w2s_mean[-1])
print('w2s_std', w2s_std[-1])
# Out:
# w1s_mean 0.07966781975294608
# w1s_std 0.021685404478852872
# w2s_mean 0.21431967282091877
# w2s_std 0.06981352145867077

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

fig, ax = plt.subplots(1, 2, figsize=(18, 5))

x = np.arange(0, 80, 10)

ax[0].plot(x, w1s_mean)
ax[0].fill_between(x, w1s_mean - w1s_std, w1s_mean + w1s_std, color='C0', alpha=0.4)
ax[0].set_xlabel('epoch', fontsize=14)
ax[0].set_ylabel('1-Wasserstein distance', fontsize=14)

ax[1].plot(x, w2s_mean)
ax[1].fill_between(x, w2s_mean - w2s_std, w2s_mean + w2s_std, color='C0', alpha=0.4)
ax[1].set_xlabel('epoch', fontsize=14)
ax[1].set_ylabel('2-Wasserstein-2 distance', fontsize=14)
plt.show()

# %%
print(losses_runs.shape)
plt.plot(losses_runs[1])
plt.xlabel('iteration')
plt.ylabel('loss')
plt.show()
# Out:
# (5, 3200)

# %%
# inference on the full dataset for visualization
plt.style.use('default')
n_test = data.shape[0]
traj = torch.tensor(Rotation.random(n_test).as_matrix()).to(device).reshape(-1, 9)
for t in torch.linspace(0, 1, 200):
    t = torch.tensor([t]).to(device).repeat(n_test)
    dt = torch.tensor([1/200]).to(device)
    traj = inference(model, traj, t, dt)
final_traj = rearrange(traj, 'b (c d) -> b c d', c=3, d=3)
fig = plot_so3(final_traj)
plt.show()
